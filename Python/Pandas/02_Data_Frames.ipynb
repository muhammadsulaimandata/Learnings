# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Creating Data Frames
# DataFrames are 2-dimensional labeled data structures in Pandas. They can be thought of as a collection of Series objects that share the same index. We can create a DataFrame from a variety of data sources, including lists, dictionaries, and NumPy arrays.

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 34, 40],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston'],
    'Salary' : [70000, 80000, 90000, 100000]
}

# %%
df_dic = pd.DataFrame(data)
df_dic
# Out:
#       Name  Age         City  Salary
# 0    Alice   25     New York   70000
# 1      Bob   30  Los Angeles   80000
# 2  Charlie   34      Chicago   90000
# 3    David   40      Houston  100000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

df_list = pd.DataFrame(data_list) # Creating DataFrame from list of lists without column names
print(df_list, "\n")

# Now giving names to columns while creating DataFrame
df_list_named = pd.DataFrame(data_list, columns=['Name', 'Age', 'City', 'Salary'])
print(df_list_named)
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000
#
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# #### Selection and Indexing of Columns

# %%
my_df = pd.DataFrame(data_list, columns=['Name', 'Age', 'City', 'Salary'])

# %%
# Calling separate columns using column names
my_df['Age']
# Out:
# 0    28
# 1    34
# 2    29
# 3    42
# Name: Age, dtype: int64

# %% [markdown]
# **Selecting a Column**

# %%
my_df['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %% [markdown]
# **Selecting Multiple columns**

# %%
# Selecting multiple columns
my_df[['Name', 'City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# **Creating New Columns**

# %%
my_df['Designation'] = ['Engineer', 'Designer', 'Manager', 'Director']

# %%
my_df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000    Engineer
# 1   Anna   34     Paris   70000    Designer
# 2  Peter   29    Berlin   62000     Manager
# 3  Linda   42    London   85000    Director

# %% [markdown]
# **Deleting a Column**

# %%
my_df.drop('Designation', axis = 1) # Using Drop() this will not be removed from original dataframe so for this we have to use inplace function
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
print(my_df)
my_df.drop('Designation', axis = 1, inplace = True) # Using inplace = True will remove the column from original dataframe
print(my_df)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 print(my_df)
# ----> 2 my_df.drop('Designation', axis = 1, inplace = True) # Using inplace = True will remove the column from original dataframe
#       3 print(my_df)
#
# File c:\Users\Sulaiman\miniconda3\envs\data_analysis\lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)
#    5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)
#    5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Users\Sulaiman\miniconda3\envs\data_analysis\lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Users\Sulaiman\miniconda3\envs\data_analysis\lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Users\Sulaiman\miniconda3\envs\data_analysis\lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Designation'] not found in axis"
