# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"countries.csv")
df
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
df.shape
# Out:
# (194, 64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
df.describe()
# Out:
#          latitude   longitude  agricultural_land   forest_area     land_area  \
# count  194.000000  194.000000       1.930000e+02  1.940000e+02  1.940000e+02
# mean    18.975601   22.027491       2.454551e+05  2.086784e+05  6.675087e+05
# std     23.876225   66.396389       6.356268e+05  7.824926e+05  1.837107e+06
# min    -41.000000 -175.000000       4.000000e+00  0.000000e+00  2.027000e+00
# 25%      4.000000   -5.000000       6.464000e+03  3.331775e+03  2.355250e+04
# 50%     16.583333   21.500000       3.872780e+04  2.528925e+04  1.203750e+05
# 75%     40.000000   50.162500       2.150000e+05  1.236735e+05  5.237000e+05
# max     65.000000  178.000000       5.285080e+06  8.153120e+06  1.637690e+07
#
#          rural_land     urban_land  central_government_debt_pct_gdp  \
# count  1.940000e+02     194.000000                       120.000000
# mean   6.563711e+05    9777.116531                        66.759366
# std    1.811169e+06   42301.458421                        71.806247
# ...

# %%
# Country with the highest population
print(df[df['population'] == df['population'].max()])
print(df[df['population'] == df['population'].max()]['country'])
# Out:
#    country       country_long      currency capital_city         region  \
# 75   India  Republic of India  Indian rupee    New Delhi  Southern Asia
#
#    continent demonym  latitude  longitude  agricultural_land  ...  population  \
# 75      Asia  Indian      20.0       77.0          1790450.0  ...  1417173173
#
#     women_parliament_seats_pct  rural_population  urban_population  press  \
# 75                     14.9446         908804812         508368361   1.71
#
#     democracy_score    democracy_type  median_age  political_leader  \
# 75             7.23  Flawed democracy        23.9     Narendra Modi
#
#              title
# 75  Prime Minister
#
# [1 rows x 64 columns]
# 75    India
# Name: country, dtype: object

# %%
print(df[df['population'] == df['population'].min()]['country'])
print(df[df['population'] == df['population'].min()]['capital_city'])
# Out:
# 179    Tuvalu
# Name: country, dtype: object
# 179    Funafuti
# Name: capital_city, dtype: object

# %%
df.sort_values(by = 'democracy_score', ascending = False, inplace = True)
df.head(10)
print(df['country'].head(10))
# Out:
# 127         Norway
# 74         Iceland
# 164         Sweden
# 122    New Zealand
# 46         Denmark
# 79         Ireland
# 30          Canada
# 59         Finland
# 8        Australia
# 165    Switzerland
# Name: country, dtype: object

# %%
print(df['region'].value_counts().count())
# Out:
# 22

# %%
df['region'].value_counts()['Eastern Europe']
# Out:
# np.int64(10)

# %%
print(df[df['region'] == 'Eastern Europe'])
print(df[df['region'] == 'Eastern Europe']['country'])
# Out:
#              country          country_long           currency capital_city  \
# 43    Czech Republic        Czech Republic       Czech koruna       Prague
# 151  Slovak Republic       Slovak Republic               Euro   Bratislava
# 24          Bulgaria  Republic of Bulgaria      Bulgarian lev        Sofia
# 136           Poland    Republic of Poland       Polish zloty       Warsaw
# 73           Hungary               Hungary   Hungarian forint     Budapest
# 139          Romania               Romania   New Romanian leu    Bucharest
# 111          Moldova   Republic of Moldova       Moldovan leu     Chișinău
# 181          Ukraine               Ukraine  Ukrainian hryvnia         Kiev
# 14           Belarus   Republic of Belarus   Belarusian rubel        Minsk
# 140           Russia    Russian Federation      Russian ruble       Moscow
#
#              region continent     demonym   latitude  longitude  \
# 43   Eastern Europe    Europe       Czech  49.750000       15.5
# ...

# %%
# Want to know about second populated country of the world
df[df['population'] == df['population'].nlargest(5).iloc[1]]
# Out:
#    country                country_long      currency capital_city  \
# 34   China  People's Republic of China  Chinese yuan      Beijing
#
#           region continent  demonym  latitude  longitude  agricultural_land  \
# 34  Eastern Asia      Asia  Chinese      35.0      105.0          5285080.0
#
#     ...  population  women_parliament_seats_pct  rural_population  \
# 34  ...  1412175000                     24.9412         514596570
#
#     urban_population  press  democracy_score  democracy_type  median_age  \
# 34         897578430   0.99             3.32   Authoritarian        34.5
#
#     political_leader                                     title
# 34        Xi Jinping  General Secretary of the Communist Party
#
# [1 rows x 64 columns]

# %%
# Want to know the leader of third populated country of the world
df[df['population'] == df['population'].nlargest(5).iloc[2]]['political_leader']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Sulaiman\miniconda3\envs\data_analysis\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'political_leader'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 2
#       1 # Want to know the leader of third populated country of the world
# ...
