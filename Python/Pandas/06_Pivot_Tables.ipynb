# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **1. Pivot Tables**

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    835     73   John  January      Q1
# 1  2023-01-02       B   West    466     53   Mary  January      Q1
# 2  2023-01-03       C  North    605     26    Bob  January      Q1
# 3  2023-01-04       D  South    936     49  Alice  January      Q1
# 4  2023-01-05       A   East    768     90   John  January      Q1
# 5  2023-01-06       B   West    761     84   Mary  January      Q1
# 6  2023-01-07       C  North    104     57    Bob  January      Q1
# 7  2023-01-08       D  South    758     83  Alice  January      Q1
# 8  2023-01-09       A   East    761     77   John  January      Q1
# 9  2023-01-10       B   West    932     48   Mary  January      Q1
# 10 2023-01-11       C  North    140     53    Bob  January      Q1
# 11 2023-01-12       D  South    520     47  Alice  January      Q1
# 12 2023-01-13       A   East    365     49   John  January      Q1
# 13 2023-01-14       B   West    843     22   Mary  January      Q1
# 14 2023-01-15       C  North    461     81    Bob  January      Q1
# 15 2023-01-16       D  South    928     85  Alice  January      Q1
# 16 2023-01-17       A   East    771     19   John  January      Q1
# 17 2023-01-18       B   West    446     75   Mary  January      Q1
# 18 2023-01-19       C  North    512     85    Bob  January      Q1
# 19 2023-01-20       D  South    557     85  Alice  January      Q1

# %%
pd.pivot_table(df, values = 'Sales', index = 'Product', columns = 'Region')
# Out:
# Region    East  North  South   West
# Product
# A        700.0    NaN    NaN    NaN
# B          NaN    NaN    NaN  689.6
# C          NaN  364.4    NaN    NaN
# D          NaN    NaN  739.8    NaN

# %%
pivot2 = pd.pivot_table(df, values = ['Sales', 'Units'], index = 'Region', columns = 'Product', aggfunc='sum')
pivot2
# Out:
#           Sales                          Units
# Product       A       B       C       D      A      B      C      D
# Region
# East     3500.0     NaN     NaN     NaN  308.0    NaN    NaN    NaN
# North       NaN     NaN  1822.0     NaN    NaN    NaN  302.0    NaN
# South       NaN     NaN     NaN  3699.0    NaN    NaN    NaN  349.0
# West        NaN  3448.0     NaN     NaN    NaN  282.0    NaN    NaN

# %% [markdown]
# **2. Crosstab**

# %%
print(pd.crosstab(df['Product'], df['Region']))
# Out:
# Region   East  North  South  West
# Product
# A           5      0      0     0
# B           0      0      0     5
# C           0      5      0     0
# D           0      0      5     0
