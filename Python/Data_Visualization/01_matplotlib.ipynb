# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **1. Basic Matplot Functions**

# %%
x = np.linspace(0, 5, 11)
print(f'X Array: {x}')

y = x ** 2
print(f'\nY Array: {y}')
# Out:
# X Array: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
#
# Y Array: [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %%
plt.plot(x, y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('My Plot Title')
plt.legend(['Y = X^2'])

# %% [markdown]
# **2. Subplots in Matplotlib**

# %%
plt.subplot(2, 2, 1)
plt.plot(x, y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Plot 1')

plt.subplot(2, 2, 2)
plt.plot(y, x)
plt.xlabel('Y Label')
plt.ylabel('X Label')
plt.title('Plot 2')

plt.subplot(2, 2, 3)
plt.plot(x**2, y)
plt.xlabel('X Square as X Label')
plt.ylabel('Y Label')
plt.title('Plot 3')

plt.subplot(2, 2, 4)
plt.plot(x, y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Plot 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# **3. Object Oriented Way**

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#
# figsize is a tuple of the width and height of the figure in inches
# dpi is the dots-per-inch (pixel per inch).

# %%
# Custom Canvas Creation method
fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# Now plotting values on Canvas
axis1.plot(x, y)


# Making another Plot on Canvas
axis2 = fig.add_axes([0.2, 0.6, 0.3, 0.3])
axis2.plot(x, y)

# %% [markdown]
# **4. Types of Plots**

# %%
plt.scatter(x, y)

# %%
plt.hist(x, y)
# Out:
# (array([1., 1., 3., 3., 3., 0., 0., 0., 0., 0.]),
#  array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#         20.25, 25.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19cd762e1a0>,
#   <matplotlib.lines.Line2D at 0x19cd762efe0>],
#  'caps': [<matplotlib.lines.Line2D at 0x19cd762f0a0>,
#   <matplotlib.lines.Line2D at 0x19cd762d240>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19cd762c610>],
#  'medians': [<matplotlib.lines.Line2D at 0x19cd762ed40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19cd760a740>],
#  'means': []}

# %% [markdown]
# **5. Saving Plot**

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])


axis1.plot(x, y)
plt.savefig("Basic_Plot.png")
